# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error

"Libraries to help with jupyter notebook usage"
# Increases jupyter notebook display width
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

from IPython.display import Image # Helps display images in notebook
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import sys
"Appends both parent and grandparent dir to current path, to allow importing"
sys.path.append('..')
sys.path.append('../..')

from jupyternotebook_utils import *
from utils import *
from data_processing import *
from spotify_data import *
from spotify_utils import *

# %%
spotify_scopes = "playlist-read-private playlist-modify-private playlist-modify-public user-read-recently-played user-top-read user-library-modify"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri="http://127.0.0.1:8000/callback",
                                               scope=spotify_scopes))

audio_features_list = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 
                       'acousticness', 'instrumentalness', 'liveness', 'valence',
                       'tempo', 'duration_ms']

# %%
user_playlists = get_user_playlists(sp)

user_playlists
# Out:
# [{'playlist_name': 'COLDPLAY 2024',
#   'playlist_uri': 'spotify:playlist:6GmE6FZnc31SRHEfS2tNii',
#   'playlist_href': 'https://open.spotify.com/playlist/6GmE6FZnc31SRHEfS2tNii',
#   'playlist_track_count': 1},
#  {'playlist_name': '//lo-fi beats 🎶🌕',
#   'playlist_uri': 'spotify:playlist:3p4ZD7MTwrL4OaiEN1dFfu',
#   'playlist_href': 'https://open.spotify.com/playlist/3p4ZD7MTwrL4OaiEN1dFfu',
#   'playlist_track_count': 425},
#  {'playlist_name': "//vibin' 🎺",
#   'playlist_uri': 'spotify:playlist:4YB4UFkYYJhy3iNaHZoGXa',
#   'playlist_href': 'https://open.spotify.com/playlist/4YB4UFkYYJhy3iNaHZoGXa',
#   'playlist_track_count': 91},
#  {'playlist_name': '//productive mario-ing',
#   'playlist_uri': 'spotify:playlist:51yNcvKUbFtC6WwJi4KHH5',
#   'playlist_href': 'https://open.spotify.com/playlist/51yNcvKUbFtC6WwJi4KHH5',
#   'playlist_track_count': 1306},
#  {'playlist_name': '//du zi da zi 🏋🏻',
#   'playlist_uri': 'spotify:playlist:1f2neve1uJPOCfkahOkdEf',
#   'playlist_href': 'https://open.spotify.com/playlist/1f2neve1uJPOCfkahOkdEf',
#   'playlist_track_count': 166},
#  {'playlist_name': "//windin' down  💨🍃",
#   'playlist_uri': 'spotify:playlist:699RMfk5lxJ9uf7ZwMktYa',
#   'playlist_href': 'https://open.spotify.com/playlist/699RMfk5lxJ9uf7ZwMktYa',
#   'playlist_track_count': 34},
#  {'playlist_name': '//pumped up kicks 🥁',
#   'playlist_uri': 'spotify:playlist:6FS0wzsoprqRG9PAFsmVSz',
#   'playlist_href': 'https://open.spotify.com/playlist/6FS0wzsoprqRG9PAFsmVSz',
#   'playlist_track_count': 48},
#  {'playlist_name': '//华文fu',
#   'playlist_uri': 'spotify:playlist:0COeGz9neUCleVpgZmDlzm',
#   'playlist_href': 'https://open.spotify.com/playlist/0COeGz9neUCleVpgZmDlzm',
#   'playlist_track_count': 214},
#  {'playlist_name': '//日本語  🇯🇵',
#   'playlist_uri': 'spotify:playlist:0AfGrhDpHs17mj7pHeScPZ',
#   'playlist_href': 'https://open.spotify.com/playlist/0AfGrhDpHs17mj7pHeScPZ',
#   'playlist_track_count': 4}]

# %%
target_playlist = 'spotify:playlist:4YB4UFkYYJhy3iNaHZoGXa'
playlist_audio_features = get_user_playlist_audio_features(sp, target_playlist)

playlist_audio_features
# Out:
# [{'id': 1,
#   'danceability': 0.606,
#   'energy': 0.569,
#   'key': 1,
#   'loudness': -10.08,
#   'speechiness': 0.0393,
#   'acousticness': 0.208,
#   'instrumentalness': 0.000278,
#   'liveness': 0.17,
#   'valence': 0.603,
#   'tempo': 73.789,
#   'duration_ms': 218667},
#  {'id': 2,
#   'danceability': 0.514,
#   'energy': 0.612,
#   'key': 4,
#   'loudness': -5.981,
#   'speechiness': 0.0298,
#   'acousticness': 0.142,
#   'instrumentalness': 0,
#   'liveness': 0.0868,
#   'valence': 0.342,
#   'tempo': 125.99,
#   'duration_ms': 185005},
#  {'id': 3,
#   'danceability': 0.404,
#   'energy': 0.806,
#   'key': 2,
#   'loudness': -4.75,
#   'speechiness': 0.0496,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.112,
#   'tempo': 148.036,
#   'duration_ms': 220730},
#  {'id': 4,
#   'danceability': 0.333,
#   'energy': 0.637,
#   'key': 1,
#   'loudness': -4.904,
#   'speechiness': 0.0581,
#   'acousticness': 0.131,
#   'instrumentalness': 1.8e-05,
#   'liveness': 0.149,
#   'valence': 0.132,
#   'tempo': 139.898,
#   'duration_ms': 172693},
#  {'id': 5,
#   'danceability': 0.641,
#   'energy': 0.324,
#   'key': 11,
#   'loudness': -5.851,
#   'speechiness': 0.0299,
#   'acousticness': 0.698,
#   'instrumentalness': 0,
#   'liveness': 0.328,
#   'valence': 0.273,
#   'tempo': 110.184,
#   'duration_ms': 185487},
#  {'id': 6,
#   'danceability': 0.508,
#   'energy': 0.323,
#   'key': 1,
#   'loudness': -13.239,
#   'speechiness': 0.0347,
#   'acousticness': 0.714,
#   'instrumentalness': 1.93e-05,
#   'liveness': 0.118,
#   'valence': 0.472,
#   'tempo': 120.861,
#   'duration_ms': 159761},
#  {'id': 7,
#   'danceability': 0.34,
#   'energy': 0.354,
#   'key': 4,
#   'loudness': -9.079,
#   'speechiness': 0.0306,
#   'acousticness': 0.0454,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.216,
#   'tempo': 103.838,
#   'duration_ms': 233999},
#  {'id': 8,
#   'danceability': 0.623,
#   'energy': 0.572,
#   'key': 2,
#   'loudness': -9.257,
#   'speechiness': 0.0606,
#   'acousticness': 0.525,
#   'instrumentalness': 0,
#   'liveness': 0.185,
#   'valence': 0.461,
#   'tempo': 78.02,
#   'duration_ms': 191827},
#  {'id': 9,
#   'danceability': 0.439,
#   'energy': 0.751,
#   'key': 9,
#   'loudness': -7.632,
#   'speechiness': 0.0527,
#   'acousticness': 0.193,
#   'instrumentalness': 4.61e-05,
#   'liveness': 0.0577,
#   'valence': 0.221,
#   'tempo': 164.103,
#   'duration_ms': 263598},
#  {'id': 10,
#   'danceability': 0.764,
#   'energy': 0.534,
#   'key': 5,
#   'loudness': -8.487,
#   'speechiness': 0.032,
#   'acousticness': 0.236,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.408,
#   'tempo': 108.029,
#   'duration_ms': 166111},
#  {'id': 11,
#   'danceability': 0.472,
#   'energy': 0.204,
#   'key': 9,
#   'loudness': -13.419,
#   'speechiness': 0.0408,
#   'acousticness': 0.966,
#   'instrumentalness': 4.12e-05,
#   'liveness': 0.69,
#   'valence': 0.296,
#   'tempo': 129.504,
#   'duration_ms': 253907},
#  {'id': 12,
#   'danceability': 0.338,
#   'energy': 0.721,
#   'key': 4,
#   'loudness': -5.735,
#   'speechiness': 0.0587,
#   'acousticness': 0.00182,
#   'instrumentalness': 2.03e-05,
#   'liveness': 0.349,
#   'valence': 0.381,
#   'tempo': 80.774,
#   'duration_ms': 220468},
#  {'id': 13,
#   'danceability': 0.446,
#   'energy': 0.71,
#   'key': 5,
#   'loudness': -7.234,
#   'speechiness': 0.042,
#   'acousticness': 0.0491,
#   'instrumentalness': 0.00152,
#   'liveness': 0.109,
#   'valence': 0.465,
#   'tempo': 91.397,
#   'duration_ms': 190345},
#  {'id': 14,
#   'danceability': 0.625,
#   'energy': 0.404,
#   'key': 7,
#   'loudness': -8.827,
#   'speechiness': 0.0335,
#   'acousticness': 0.83,
#   'instrumentalness': 0,
#   'liveness': 0.12,
#   'valence': 0.37,
#   'tempo': 118.951,
#   'duration_ms': 205333},
#  {'id': 15,
#   'danceability': 0.568,
#   'energy': 0.187,
#   'key': 2,
#   'loudness': -13.438,
#   'speechiness': 0.439,
#   'acousticness': 0.678,
#   'instrumentalness': 0,
#   'liveness': 0.388,
#   'valence': 0.761,
#   'tempo': 210.871,
#   'duration_ms': 142659},
#  {'id': 16,
#   'danceability': 0.439,
#   'energy': 0.61,
#   'key': 9,
#   'loudness': -7.236,
#   'speechiness': 0.116,
#   'acousticness': 0.593,
#   'instrumentalness': 1.07e-05,
#   'liveness': 0.341,
#   'valence': 0.172,
#   'tempo': 181.088,
#   'duration_ms': 215508},
#  {'id': 17,
#   'danceability': 0.422,
#   'energy': 0.302,
#   'key': 11,
#   'loudness': -9.214,
#   'speechiness': 0.0372,
#   'acousticness': 0.629,
#   'instrumentalness': 7.83e-05,
#   'liveness': 0.104,
#   'valence': 0.123,
#   'tempo': 114.089,
#   'duration_ms': 248827},
#  {'id': 18,
#   'danceability': 0.773,
#   'energy': 0.437,
#   'key': 9,
#   'loudness': -8.281,
#   'speechiness': 0.0963,
#   'acousticness': 0.836,
#   'instrumentalness': 2.42e-05,
#   'liveness': 0.544,
#   'valence': 0.707,
#   'tempo': 103.861,
#   'duration_ms': 169973},
#  {'id': 19,
#   'danceability': 0.508,
#   'energy': 0.298,
#   'key': 1,
#   'loudness': -12.727,
#   'speechiness': 0.0342,
#   'acousticness': 0.766,
#   'instrumentalness': 6.52e-06,
#   'liveness': 0.126,
#   'valence': 0.445,
#   'tempo': 120.736,
#   'duration_ms': 159413},
#  {'id': 20,
#   'danceability': 0.45,
#   'energy': 0.718,
#   'key': 3,
#   'loudness': -5.95,
#   'speechiness': 0.0295,
#   'acousticness': 0.0304,
#   'instrumentalness': 0,
#   'liveness': 0.0942,
#   'valence': 0.37,
#   'tempo': 156.009,
#   'duration_ms': 230899},
#  {'id': 21,
#   'danceability': 0.686,
#   'energy': 0.572,
#   'key': 10,
#   'loudness': -8.003,
#   'speechiness': 0.0308,
#   'acousticness': 0.635,
#   'instrumentalness': 0.00117,
#   'liveness': 0.194,
#   'valence': 0.264,
#   'tempo': 100.56,
#   'duration_ms': 160928},
#  {'id': 22,
#   'danceability': 0.601,
#   'energy': 0.375,
#   'key': 4,
#   'loudness': -12.077,
#   'speechiness': 0.0316,
#   'acousticness': 0.877,
#   'instrumentalness': 0,
#   'liveness': 0.0943,
#   'valence': 0.164,
#   'tempo': 104.927,
#   'duration_ms': 237996},
#  {'id': 23,
#   'danceability': 0.641,
#   'energy': 0.537,
#   'key': 0,
#   'loudness': -5.452,
#   'speechiness': 0.0282,
#   'acousticness': 0.0875,
#   'instrumentalness': 9.05e-06,
#   'liveness': 0.115,
#   'valence': 0.0681,
#   'tempo': 112.864,
#   'duration_ms': 196188},
#  {'id': 24,
#   'danceability': 0.286,
#   'energy': 0.445,
#   'key': 6,
#   'loudness': -8.087,
#   'speechiness': 0.0347,
#   'acousticness': 0.355,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.278,
#   'tempo': 50.827,
#   'duration_ms': 217352},
#  {'id': 25,
#   'danceability': 0.685,
#   'energy': 0.341,
#   'key': 2,
#   'loudness': -10.434,
#   'speechiness': 0.0354,
#   'acousticness': 0.798,
#   'instrumentalness': 0,
#   'liveness': 0.0951,
#   'valence': 0.42,
#   'tempo': 123.015,
#   'duration_ms': 202927},
#  {'id': 26,
#   'danceability': 0.582,
#   'energy': 0.527,
#   'key': 3,
#   'loudness': -7.658,
#   'speechiness': 0.0372,
#   'acousticness': 0.547,
#   'instrumentalness': 0,
#   'liveness': 0.498,
#   'valence': 0.446,
#   'tempo': 100.926,
#   'duration_ms': 167320},
#  {'id': 27,
#   'danceability': 0.482,
#   'energy': 0.37,
#   'key': 4,
#   'loudness': -10.913,
#   'speechiness': 0.0271,
#   'acousticness': 0.412,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.266,
#   'tempo': 90.066,
#   'duration_ms': 183125},
#  {'id': 28,
#   'danceability': 0.73,
#   'energy': 0.437,
#   'key': 9,
#   'loudness': -7.895,
#   'speechiness': 0.0386,
#   'acousticness': 0.45,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.795,
#   'tempo': 122.989,
#   'duration_ms': 216107},
#  {'id': 29,
#   'danceability': 0.614,
#   'energy': 0.379,
#   'key': 4,
#   'loudness': -10.48,
#   'speechiness': 0.0476,
#   'acousticness': 0.607,
#   'instrumentalness': 0.000464,
#   'liveness': 0.0986,
#   'valence': 0.201,
#   'tempo': 107.989,
#   'duration_ms': 258987},
#  {'id': 30,
#   'danceability': 0.49,
#   'energy': 0.216,
#   'key': 1,
#   'loudness': -8.119,
#   'speechiness': 0.0325,
#   'acousticness': 0.792,
#   'instrumentalness': 0,
#   'liveness': 0.0997,
#   'valence': 0.068,
#   'tempo': 105.614,
#   'duration_ms': 241990},
#  {'id': 31,
#   'danceability': 0.621,
#   'energy': 0.827,
#   'key': 11,
#   'loudness': -7.309,
#   'speechiness': 0.0454,
#   'acousticness': 0.0409,
#   'instrumentalness': 0,
#   'liveness': 0.0815,
#   'valence': 0.65,
#   'tempo': 99.979,
#   'duration_ms': 199113},
#  {'id': 32,
#   'danceability': 0.52,
#   'energy': 0.124,
#   'key': 5,
#   'loudness': -18.502,
#   'speechiness': 0.0383,
#   'acousticness': 0.9,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.524,
#   'tempo': 149.251,
#   'duration_ms': 148900},
#  {'id': 33,
#   'danceability': 0.605,
#   'energy': 0.377,
#   'key': 11,
#   'loudness': -6.213,
#   'speechiness': 0.0443,
#   'acousticness': 0.733,
#   'instrumentalness': 0,
#   'liveness': 0.0808,
#   'valence': 0.519,
#   'tempo': 73.877,
#   'duration_ms': 194853},
#  {'id': 34,
#   'danceability': 0.61,
#   'energy': 0.488,
#   'key': 3,
#   'loudness': -6.918,
#   'speechiness': 0.0293,
#   'acousticness': 0.817,
#   'instrumentalness': 0,
#   'liveness': 0.312,
#   'valence': 0.443,
#   'tempo': 125.039,
#   'duration_ms': 240227},
#  {'id': 35,
#   'danceability': 0.582,
#   'energy': 0.338,
#   'key': 4,
#   'loudness': -11.457,
#   'speechiness': 0.0381,
#   'acousticness': 0.716,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.239,
#   'tempo': 82.945,
#   'duration_ms': 191930},
#  {'id': 36,
#   'danceability': 0.702,
#   'energy': 0.468,
#   'key': 6,
#   'loudness': -9.891,
#   'speechiness': 0.0306,
#   'acousticness': 0.106,
#   'instrumentalness': 0.000176,
#   'liveness': 0.123,
#   'valence': 0.617,
#   'tempo': 126.002,
#   'duration_ms': 173445},
#  {'id': 37,
#   'danceability': 0.768,
#   'energy': 0.256,
#   'key': 6,
#   'loudness': -10.157,
#   'speechiness': 0.0393,
#   'acousticness': 0.828,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.47,
#   'tempo': 106.063,
#   'duration_ms': 152741},
#  {'id': 38,
#   'danceability': 0.598,
#   'energy': 0.115,
#   'key': 2,
#   'loudness': -13.856,
#   'speechiness': 0.0461,
#   'acousticness': 0.95,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.229,
#   'tempo': 103.402,
#   'duration_ms': 256759},
#  {'id': 39,
#   'danceability': 0.61,
#   'energy': 0.822,
#   'key': 4,
#   'loudness': -6.247,
#   'speechiness': 0.0506,
#   'acousticness': 0.0649,
#   'instrumentalness': 7.12e-06,
#   'liveness': 0.161,
#   'valence': 0.74,
#   'tempo': 162.985,
#   'duration_ms': 183180},
#  {'id': 40,
#   'danceability': 0.392,
#   'energy': 0.839,
#   'key': 7,
#   'loudness': -1.921,
#   'speechiness': 0.193,
#   'acousticness': 0.158,
#   'instrumentalness': 0,
#   'liveness': 0.3,
#   'valence': 0.232,
#   'tempo': 168.001,
#   'duration_ms': 238693},
#  {'id': 41,
#   'danceability': 0.691,
#   'energy': 0.452,
#   'key': 11,
#   'loudness': -8.026,
#   'speechiness': 0.0472,
#   'acousticness': 0.356,
#   'instrumentalness': 0,
#   'liveness': 0.308,
#   'valence': 0.55,
#   'tempo': 112.966,
#   'duration_ms': 213451},
#  {'id': 42,
#   'danceability': 0.687,
#   'energy': 0.792,
#   'key': 1,
#   'loudness': -4.023,
#   'speechiness': 0.0353,
#   'acousticness': 0.000802,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.864,
#   'tempo': 133.962,
#   'duration_ms': 227333},
#  {'id': 43,
#   'danceability': 0.575,
#   'energy': 0.274,
#   'key': 0,
#   'loudness': -10.242,
#   'speechiness': 0.035,
#   'acousticness': 0.908,
#   'instrumentalness': 8.67e-05,
#   'liveness': 0.146,
#   'valence': 0.214,
#   'tempo': 87.13,
#   'duration_ms': 162759},
#  {'id': 44,
#   'danceability': 0.603,
#   'energy': 0.148,
#   'key': 7,
#   'loudness': -10.449,
#   'speechiness': 0.0279,
#   'acousticness': 0.927,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.228,
#   'tempo': 95.451,
#   'duration_ms': 184895},
#  {'id': 45,
#   'danceability': 0.602,
#   'energy': 0.694,
#   'key': 2,
#   'loudness': -5.874,
#   'speechiness': 0.0331,
#   'acousticness': 0.733,
#   'instrumentalness': 0,
#   'liveness': 0.191,
#   'valence': 0.599,
#   'tempo': 150.008,
#   'duration_ms': 214907},
#  {'id': 46,
#   'danceability': 0.568,
#   'energy': 0.672,
#   'key': 4,
#   'loudness': -7.563,
#   'speechiness': 0.029,
#   'acousticness': 0.0964,
#   'instrumentalness': 0.000226,
#   'liveness': 0.104,
#   'valence': 0.583,
#   'tempo': 101.981,
#   'duration_ms': 201412},
#  {'id': 47,
#   'danceability': 0.507,
#   'energy': 0.387,
#   'key': 10,
#   'loudness': -6.237,
#   'speechiness': 0.0324,
#   'acousticness': 0.909,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.485,
#   'tempo': 102.987,
#   'duration_ms': 207538},
#  {'id': 48,
#   'danceability': 0.529,
#   'energy': 0.351,
#   'key': 1,
#   'loudness': -12.484,
#   'speechiness': 0.0368,
#   'acousticness': 0.543,
#   'instrumentalness': 0,
#   'liveness': 0.0851,
#   'valence': 0.529,
#   'tempo': 147.815,
#   'duration_ms': 199981},
#  {'id': 49,
#   'danceability': 0.559,
#   'energy': 0.287,
#   'key': 11,
#   'loudness': -8.436,
#   'speechiness': 0.0361,
#   'acousticness': 0.93,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.466,
#   'tempo': 135.798,
#   'duration_ms': 202089},
#  {'id': 50,
#   'danceability': 0.641,
#   'energy': 0.28,
#   'key': 10,
#   'loudness': -8.737,
#   'speechiness': 0.0312,
#   'acousticness': 0.815,
#   'instrumentalness': 0,
#   'liveness': 0.0866,
#   'valence': 0.497,
#   'tempo': 120.005,
#   'duration_ms': 186500},
#  {'id': 51,
#   'danceability': 0.82,
#   'energy': 0.26,
#   'key': 9,
#   'loudness': -14.473,
#   'speechiness': 0.0759,
#   'acousticness': 0.757,
#   'instrumentalness': 0,
#   'liveness': 0.144,
#   'valence': 0.641,
#   'tempo': 114.943,
#   'duration_ms': 188442},
#  {'id': 52,
#   'danceability': 0.808,
#   'energy': 0.426,
#   'key': 2,
#   'loudness': -9.692,
#   'speechiness': 0.0488,
#   'acousticness': 0.873,
#   'instrumentalness': 3.33e-06,
#   'liveness': 0.126,
#   'valence': 0.658,
#   'tempo': 120.071,
#   'duration_ms': 164744},
#  {'id': 53,
#   'danceability': 0.566,
#   'energy': 0.586,
#   'key': 11,
#   'loudness': -7.726,
#   'speechiness': 0.0372,
#   'acousticness': 0.0171,
#   'instrumentalness': 0,
#   'liveness': 0.202,
#   'valence': 0.428,
#   'tempo': 147.942,
#   'duration_ms': 203853},
#  {'id': 54,
#   'danceability': 0.44,
#   'energy': 0.317,
#   'key': 8,
#   'loudness': -9.258,
#   'speechiness': 0.0531,
#   'acousticness': 0.891,
#   'instrumentalness': 4.78e-06,
#   'liveness': 0.141,
#   'valence': 0.268,
#   'tempo': 169.914,
#   'duration_ms': 233456},
#  {'id': 55,
#   'danceability': 0.573,
#   'energy': 0.911,
#   'key': 10,
#   'loudness': -5.007,
#   'speechiness': 0.0409,
#   'acousticness': 0.0151,
#   'instrumentalness': 9.9e-05,
#   'liveness': 0.335,
#   'valence': 0.818,
#   'tempo': 164.007,
#   'duration_ms': 292954},
#  {'id': 56,
#   'danceability': 0.739,
#   'energy': 0.336,
#   'key': 11,
#   'loudness': -11.808,
#   'speechiness': 0.0475,
#   'acousticness': 0.833,
#   'instrumentalness': 0,
#   'liveness': 0.265,
#   'valence': 0.485,
#   'tempo': 96.085,
#   'duration_ms': 214880},
#  {'id': 57,
#   'danceability': 0.515,
#   'energy': 0.593,
#   'key': 4,
#   'loudness': -4.801,
#   'speechiness': 0.0322,
#   'acousticness': 0.653,
#   'instrumentalness': 0.162,
#   'liveness': 0.25,
#   'valence': 0.153,
#   'tempo': 94.467,
#   'duration_ms': 209260},
#  {'id': 58,
#   'danceability': 0.645,
#   'energy': 0.686,
#   'key': 4,
#   'loudness': -6.517,
#   'speechiness': 0.0653,
#   'acousticness': 0.469,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.686,
#   'tempo': 84.915,
#   'duration_ms': 183208},
#  {'id': 59,
#   'danceability': 0.836,
#   'energy': 0.637,
#   'key': 9,
#   'loudness': -7.86,
#   'speechiness': 0.0323,
#   'acousticness': 0.492,
#   'instrumentalness': 0,
#   'liveness': 0.0992,
#   'valence': 0.75,
#   'tempo': 111.979,
#   'duration_ms': 161729},
#  {'id': 60,
#   'danceability': 0.574,
#   'energy': 0.347,
#   'key': 10,
#   'loudness': -12.099,
#   'speechiness': 0.0461,
#   'acousticness': 0.865,
#   'instrumentalness': 0,
#   'liveness': 0.346,
#   'valence': 0.293,
#   'tempo': 109.884,
#   'duration_ms': 168000},
#  {'id': 61,
#   'danceability': 0.746,
#   'energy': 0.45,
#   'key': 7,
#   'loudness': -8.543,
#   'speechiness': 0.0872,
#   'acousticness': 0.0407,
#   'instrumentalness': 0,
#   'liveness': 0.172,
#   'valence': 0.336,
#   'tempo': 95.998,
#   'duration_ms': 232853},
#  {'id': 62,
#   'danceability': 0.67,
#   'energy': 0.874,
#   'key': 8,
#   'loudness': -5.221,
#   'speechiness': 0.0305,
#   'acousticness': 0.00231,
#   'instrumentalness': 1.72e-05,
#   'liveness': 0.3,
#   'valence': 0.789,
#   'tempo': 130.041,
#   'duration_ms': 261013},
#  {'id': 63,
#   'danceability': 0.598,
#   'energy': 0.847,
#   'key': 1,
#   'loudness': -2.54,
#   'speechiness': 0.205,
#   'acousticness': 0.0655,
#   'instrumentalness': 9.92e-05,
#   'liveness': 0.307,
#   'valence': 0.728,
#   'tempo': 169.959,
#   'duration_ms': 205480},
#  {'id': 64,
#   'danceability': 0.537,
#   'energy': 0.793,
#   'key': 8,
#   'loudness': -3.446,
#   'speechiness': 0.04,
#   'acousticness': 0.217,
#   'instrumentalness': 0.000361,
#   'liveness': 0.143,
#   'valence': 0.73,
#   'tempo': 180.029,
#   'duration_ms': 242667},
#  {'id': 65,
#   'danceability': 0.765,
#   'energy': 0.393,
#   'key': 6,
#   'loudness': -9.616,
#   'speechiness': 0.0311,
#   'acousticness': 0.633,
#   'instrumentalness': 0,
#   'liveness': 0.142,
#   'valence': 0.224,
#   'tempo': 121.909,
#   'duration_ms': 153863},
#  {'id': 66,
#   'danceability': 0.682,
#   'energy': 0.927,
#   'key': 4,
#   'loudness': -2.915,
#   'speechiness': 0.0479,
#   'acousticness': 0.0843,
#   'instrumentalness': 0,
#   'liveness': 0.149,
#   'valence': 0.744,
#   'tempo': 101.019,
#   'duration_ms': 195613},
#  {'id': 67,
#   'danceability': 0.684,
#   'energy': 0.512,
#   'key': 11,
#   'loudness': -8.715,
#   'speechiness': 0.0525,
#   'acousticness': 0.544,
#   'instrumentalness': 0,
#   'liveness': 0.097,
#   'valence': 0.466,
#   'tempo': 119.901,
#   'duration_ms': 160225},
#  {'id': 68,
#   'danceability': 0.583,
#   'energy': 0.491,
#   'key': 7,
#   'loudness': -7.305,
#   'speechiness': 0.0265,
#   'acousticness': 0.671,
#   'instrumentalness': 0,
#   'liveness': 0.157,
#   'valence': 0.286,
#   'tempo': 135.97,
#   'duration_ms': 185884},
#  {'id': 69,
#   'danceability': 0.429,
#   'energy': 0.486,
#   'key': 1,
#   'loudness': -9.971,
#   'speechiness': 0.101,
#   'acousticness': 0.866,
#   'instrumentalness': 0,
#   'liveness': 0.0982,
#   'valence': 0.661,
#   'tempo': 146.99,
#   'duration_ms': 209493},
#  {'id': 70,
#   'danceability': 0.648,
#   'energy': 0.308,
#   'key': 1,
#   'loudness': -11.729,
#   'speechiness': 0.04,
#   'acousticness': 0.886,
#   'instrumentalness': 0.0774,
#   'liveness': 0.124,
#   'valence': 0.198,
#   'tempo': 76.997,
#   'duration_ms': 184638},
#  {'id': 71,
#   'danceability': 0.509,
#   'energy': 0.339,
#   'key': 9,
#   'loudness': -10.677,
#   'speechiness': 0.0334,
#   'acousticness': 0.0983,
#   'instrumentalness': 0,
#   'liveness': 0.525,
#   'valence': 0.124,
#   'tempo': 133.983,
#   'duration_ms': 209166},
#  {'id': 72,
#   'danceability': 0.624,
#   'energy': 0.401,
#   'key': 8,
#   'loudness': -11.793,
#   'speechiness': 0.0307,
#   'acousticness': 0.336,
#   'instrumentalness': 0.00129,
#   'liveness': 0.144,
#   'valence': 0.133,
#   'tempo': 62.633,
#   'duration_ms': 174669},
#  {'id': 73,
#   'danceability': 0.441,
#   'energy': 0.202,
#   'key': 7,
#   'loudness': -12.499,
#   'speechiness': 0.0381,
#   'acousticness': 0.732,
#   'instrumentalness': 2.6e-05,
#   'liveness': 0.126,
#   'valence': 0.269,
#   'tempo': 77.971,
#   'duration_ms': 174587},
#  {'id': 74,
#   'danceability': 0.164,
#   'energy': 0.491,
#   'key': 7,
#   'loudness': -9.552,
#   'speechiness': 0.0425,
#   'acousticness': 0.546,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'valence': 0.203,
#   'tempo': 182.467,
#   'duration_ms': 285410},
#  {'id': 75,
#   'danceability': 0.667,
#   'energy': 0.316,
#   'key': 7,
#   'loudness': -8.952,
#   'speechiness': 0.0318,
#   'acousticness': 0.814,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.361,
#   'tempo': 95.85,
#   'duration_ms': 315476},
#  {'id': 76,
#   'danceability': 0.809,
#   'energy': 0.411,
#   'key': 10,
#   'loudness': -12.82,
#   'speechiness': 0.186,
#   'acousticness': 0.355,
#   'instrumentalness': 1.52e-06,
#   'liveness': 0.107,
#   'valence': 0.426,
#   'tempo': 104.96,
#   'duration_ms': 158469},
#  {'id': 77,
#   'danceability': 0.375,
#   'energy': 0.457,
#   'key': 3,
#   'loudness': -7.018,
#   'speechiness': 0.0315,
#   'acousticness': 0.868,
#   'instrumentalness': 0.0145,
#   'liveness': 0.191,
#   'valence': 0.415,
#   'tempo': 174.839,
#   'duration_ms': 254400},
#  {'id': 78,
#   'danceability': 0.213,
#   'energy': 0.864,
#   'key': 8,
#   'loudness': -5.71,
#   'speechiness': 0.401,
#   'acousticness': 0.0301,
#   'instrumentalness': 9.68e-05,
#   'liveness': 0.0465,
#   'valence': 0.13,
#   'tempo': 177.921,
#   'duration_ms': 129187},
#  {'id': 79,
#   'danceability': 0.535,
#   'energy': 0.359,
#   'key': 2,
#   'loudness': -9.343,
#   'speechiness': 0.0607,
#   'acousticness': 0.771,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.488,
#   'tempo': 154.163,
#   'duration_ms': 184505},
#  {'id': 80,
#   'danceability': 0.676,
#   'energy': 0.565,
#   'key': 10,
#   'loudness': -9.411,
#   'speechiness': 0.03,
#   'acousticness': 0.00321,
#   'instrumentalness': 0.000579,
#   'liveness': 0.241,
#   'valence': 0.689,
#   'tempo': 113.007,
#   'duration_ms': 246396},
#  {'id': 81,
#   'danceability': 0.7,
#   'energy': 0.546,
#   'key': 4,
#   'loudness': -9.961,
#   'speechiness': 0.0519,
#   'acousticness': 0.762,
#   'instrumentalness': 1.11e-05,
#   'liveness': 0.103,
#   'valence': 0.293,
#   'tempo': 134.152,
#   'duration_ms': 248894},
#  {'id': 82,
#   'danceability': 0.583,
#   'energy': 0.491,
#   'key': 7,
#   'loudness': -7.305,
#   'speechiness': 0.0265,
#   'acousticness': 0.671,
#   'instrumentalness': 0,
#   'liveness': 0.157,
#   'valence': 0.286,
#   'tempo': 135.97,
#   'duration_ms': 185884},
#  {'id': 83,
#   'danceability': 0.458,
#   'energy': 0.137,
#   'key': 8,
#   'loudness': -14.083,
#   'speechiness': 0.0355,
#   'acousticness': 0.882,
#   'instrumentalness': 0,
#   'liveness': 0.15,
#   'valence': 0.437,
#   'tempo': 80.824,
#   'duration_ms': 249427},
#  {'id': 84,
#   'danceability': 0.552,
#   'energy': 0.347,
#   'key': 6,
#   'loudness': -9.542,
#   'speechiness': 0.0303,
#   'acousticness': 0.79,
#   'instrumentalness': 2.15e-06,
#   'liveness': 0.111,
#   'valence': 0.173,
#   'tempo': 113.809,
#   'duration_ms': 211653},
#  {'id': 85,
#   'danceability': 0.508,
#   'energy': 0.643,
#   'key': 1,
#   'loudness': -4.119,
#   'speechiness': 0.0411,
#   'acousticness': 0.378,
#   'instrumentalness': 0,
#   'liveness': 0.085,
#   'valence': 0.53,
#   'tempo': 155.829,
#   'duration_ms': 172547},
#  {'id': 86,
#   'danceability': 0.69,
#   'energy': 0.876,
#   'key': 2,
#   'loudness': -4.159,
#   'speechiness': 0.059,
#   'acousticness': 0.0428,
#   'instrumentalness': 0,
#   'liveness': 0.147,
#   'valence': 0.493,
#   'tempo': 123.994,
#   'duration_ms': 192112},
#  {'id': 87,
#   'danceability': 0.636,
#   'energy': 0.705,
#   'key': 3,
#   'loudness': -6.284,
#   'speechiness': 0.0412,
#   'acousticness': 0.0574,
#   'instrumentalness': 0,
#   'liveness': 0.281,
#   'valence': 0.441,
#   'tempo': 112.189,
#   'duration_ms': 127249},
#  {'id': 88,
#   'danceability': 0.475,
#   'energy': 0.897,
#   'key': 9,
#   'loudness': -6.446,
#   'speechiness': 0.0629,
#   'acousticness': 0.0442,
#   'instrumentalness': 0,
#   'liveness': 0.0115,
#   'valence': 0.863,
#   'tempo': 160.866,
#   'duration_ms': 145388},
#  {'id': 89,
#   'danceability': 0.597,
#   'energy': 0.822,
#   'key': 1,
#   'loudness': -2.676,
#   'speechiness': 0.0293,
#   'acousticness': 0.378,
#   'instrumentalness': 0,
#   'liveness': 0.131,
#   'valence': 0.518,
#   'tempo': 102.01,
#   'duration_ms': 216648},
#  {'id': 90,
#   'danceability': 0.386,
#   'energy': 0.333,
#   'key': 11,
#   'loudness': -9.514,
#   'speechiness': 0.0334,
#   'acousticness': 0.897,
#   'instrumentalness': 0,
#   'liveness': 0.218,
#   'valence': 0.318,
#   'tempo': 120.14,
#   'duration_ms': 289000},
#  {'id': 91,
#   'danceability': 0.53,
#   'energy': 0.469,
#   'key': 2,
#   'loudness': -6.344,
#   'speechiness': 0.0957,
#   'acousticness': 0.185,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.188,
#   'tempo': 94.371,
#   'duration_ms': 205950}]

# %%
playlist_details = get_user_playlist_details(sp, target_playlist)

playlist_details
# Out:
# [{'id': 1,
#   'track_uri': 'spotify:track:1AamwwLMxzX4EGPUZGHbqL',
#   'track_title': 'Remember to Forget',
#   'track_url': 'https://open.spotify.com/track/1AamwwLMxzX4EGPUZGHbqL',
#   'track_popularity': 42,
#   'release_date': '2020-12-11',
#   'album_uri': 'spotify:album:4ISDgLKwxu82kiHgf9kl7Y'},
#  {'id': 2,
#   'track_uri': 'spotify:track:1b3nlcP6hogIzYRVK2Ui7K',
#   'track_title': 'Wherever You Are',
#   'track_url': 'https://open.spotify.com/track/1b3nlcP6hogIzYRVK2Ui7K',
#   'track_popularity': 0,
#   'release_date': '2020-01-10',
#   'album_uri': 'spotify:album:7MGBQrzuC41v7jmMVyPQwd'},
#  {'id': 3,
#   'track_uri': 'spotify:track:70YPzqSEwJvAIQ6nMs1cjY',
#   'track_title': 'In Your Arms (with X Ambassadors)',
#   'track_url': 'https://open.spotify.com/track/70YPzqSEwJvAIQ6nMs1cjY',
#   'track_popularity': 63,
#   'release_date': '2019-08-16',
#   'album_uri': 'spotify:album:60xcVwuQJAOyu11xf9mObS'},
#  {'id': 4,
#   'track_uri': 'spotify:track:5KCbr5ndeby4y4ggthdiAb',
#   'track_title': 'Wonder',
#   'track_url': 'https://open.spotify.com/track/5KCbr5ndeby4y4ggthdiAb',
#   'track_popularity': 72,
#   'release_date': '2020-10-02',
#   'album_uri': 'spotify:album:7vif3nVzXURIrjGjHeHytB'},
#  {'id': 5,
#   'track_uri': 'spotify:track:0E4Y1XIbs8GrAT1YqVy6dq',
#   'track_title': 'Afterglow',
#   'track_url': 'https://open.spotify.com/track/0E4Y1XIbs8GrAT1YqVy6dq',
#   'track_popularity': 73,
#   'release_date': '2020-12-21',
#   'album_uri': 'spotify:album:5bb2Sf8jps2DTyI2urMThV'},
#  {'id': 6,
#   'track_uri': 'spotify:track:7DZ8n63a46dU6iUyN9OeRl',
#   'track_title': 'The Way That I Love You - Single Version',
#   'track_url': 'https://open.spotify.com/track/7DZ8n63a46dU6iUyN9OeRl',
#   'track_popularity': 54,
#   'release_date': '2020-03-20',
#   'album_uri': 'spotify:album:2brd4GZO66lqqlAWgNiIkK'},
#  {'id': 7,
#   'track_uri': 'spotify:track:3kswR4VNp2z8f8VXUHfTSD',
#   'track_title': 'Say Something',
#   'track_url': 'https://open.spotify.com/track/3kswR4VNp2z8f8VXUHfTSD',
#   'track_popularity': 0,
#   'release_date': '2020-06-12',
#   'album_uri': 'spotify:album:18558bqLAhDW0UBIQxk0tQ'},
#  {'id': 8,
#   'track_uri': 'spotify:track:0OPIBKjAYBFzNpo1HzjqzQ',
#   'track_title': 'better with you',
#   'track_url': 'https://open.spotify.com/track/0OPIBKjAYBFzNpo1HzjqzQ',
#   'track_popularity': 56,
#   'release_date': '2020-02-28',
#   'album_uri': 'spotify:album:4pVzD6lsU9IaX6UXGiThY4'},
#  {'id': 9,
#   'track_uri': 'spotify:track:0QfmQhr5npxuWQ4zzUDUhB',
#   'track_title': 'Just A Dream',
#   'track_url': 'https://open.spotify.com/track/0QfmQhr5npxuWQ4zzUDUhB',
#   'track_popularity': 29,
#   'release_date': '2017-11-14',
#   'album_uri': 'spotify:album:1uPJ7QS3ff8CRa59GRQtUX'},
#  {'id': 10,
#   'track_uri': 'spotify:track:3QW9sihUUzSke7zlDJyCgA',
#   'track_title': 'Anywhere With You Is Home',
#   'track_url': 'https://open.spotify.com/track/3QW9sihUUzSke7zlDJyCgA',
#   'track_popularity': 12,
#   'release_date': '2017-11-23',
#   'album_uri': 'spotify:album:5VddKf37GLzUQLhZU7M70i'},
#  {'id': 11,
#   'track_uri': 'spotify:track:7htt7UuxHL5wneOcMWJP5E',
#   'track_title': 'Take On Me - MTV Unplugged',
#   'track_url': 'https://open.spotify.com/track/7htt7UuxHL5wneOcMWJP5E',
#   'track_popularity': 62,
#   'release_date': '2017-10-06',
#   'album_uri': 'spotify:album:55SHqC4ZxSnT0wWQgg9eOY'},
#  {'id': 12,
#   'track_uri': 'spotify:track:0UWHBhWCIMweUSlvMBgp4Y',
#   'track_title': 'Hell Or High Water',
#   'track_url': 'https://open.spotify.com/track/0UWHBhWCIMweUSlvMBgp4Y',
#   'track_popularity': 39,
#   'release_date': '2018-08-31',
#   'album_uri': 'spotify:album:0cxI0zxaI3utCgOmZ1DrxR'},
#  {'id': 13,
#   'track_uri': 'spotify:track:5vqfkiA8UjCuT7qV62fRUw',
#   'track_title': 'Runaway',
#   'track_url': 'https://open.spotify.com/track/5vqfkiA8UjCuT7qV62fRUw',
#   'track_popularity': 34,
#   'release_date': '2018-08-31',
#   'album_uri': 'spotify:album:0cxI0zxaI3utCgOmZ1DrxR'},
#  {'id': 14,
#   'track_uri': 'spotify:track:4pL2Gtu3UP29OtLeHYdKed',
#   'track_title': 'Year on Year, Day by Day (Patchwork Version)',
#   'track_url': 'https://open.spotify.com/track/4pL2Gtu3UP29OtLeHYdKed',
#   'track_popularity': 29,
#   'release_date': '2020-07-10',
#   'album_uri': 'spotify:album:65f1t781sotHbcAco6nnZN'},
#  {'id': 15,
#   'track_uri': 'spotify:track:6zvtPVptAvY6wRbkPGLKff',
#   'track_title': 'Morning Coffee',
#   'track_url': 'https://open.spotify.com/track/6zvtPVptAvY6wRbkPGLKff',
#   'track_popularity': 60,
#   'release_date': '2020-10-08',
#   'album_uri': 'spotify:album:0Lhj5XHmeZTOXmrXDeXpEF'},
#  {'id': 16,
#   'track_uri': 'spotify:track:61KpQadow081I2AsbeLcsb',
#   'track_title': 'deja vu',
#   'track_url': 'https://open.spotify.com/track/61KpQadow081I2AsbeLcsb',
#   'track_popularity': 17,
#   'release_date': '2021-04-01',
#   'album_uri': 'spotify:album:3lwHyR4joA1xB7Nun21EP6'},
#  {'id': 17,
#   'track_uri': 'spotify:track:1v1oIWf2Xgh54kIWuKsDf6',
#   'track_title': 'Runaway',
#   'track_url': 'https://open.spotify.com/track/1v1oIWf2Xgh54kIWuKsDf6',
#   'track_popularity': 79,
#   'release_date': '2016-03-11',
#   'album_uri': 'spotify:album:6YMSXPIHkA2jPIlFHuejXW'},
#  {'id': 18,
#   'track_uri': 'spotify:track:75ls0gurX68lUmMjE7QcsE',
#   'track_title': 'all the kids are depressed',
#   'track_url': 'https://open.spotify.com/track/75ls0gurX68lUmMjE7QcsE',
#   'track_popularity': 74,
#   'release_date': '2018-05-04',
#   'album_uri': 'spotify:album:14lSyFVCuhvEoW7ogOIzD0'},
#  {'id': 19,
#   'track_uri': 'spotify:track:7MIStNE3PRrcSE5beK12Fk',
#   'track_title': 'The Way That I Love You',
#   'track_url': 'https://open.spotify.com/track/7MIStNE3PRrcSE5beK12Fk',
#   'track_popularity': 42,
#   'release_date': '2021-01-08',
#   'album_uri': 'spotify:album:1cD1OsXdX1czUNujNuJGzJ'},
#  {'id': 20,
#   'track_uri': 'spotify:track:2oxBo0YLW89NLuv64Pvohc',
#   'track_title': 'Saving Grace',
#   'track_url': 'https://open.spotify.com/track/2oxBo0YLW89NLuv64Pvohc',
#   'track_popularity': 0,
#   'release_date': '2020-06-12',
#   'album_uri': 'spotify:album:18558bqLAhDW0UBIQxk0tQ'},
#  {'id': 21,
#   'track_uri': 'spotify:track:0eaD3F5zUC3Bq8In11nkau',
#   'track_title': 'Weather Any Storm',
#   'track_url': 'https://open.spotify.com/track/0eaD3F5zUC3Bq8In11nkau',
#   'track_popularity': 53,
#   'release_date': '2020-05-01',
#   'album_uri': 'spotify:album:1jgSrQiojLfUDfacj6I0U7'},
#  {'id': 22,
#   'track_uri': 'spotify:track:6cRkm1iHWDYpkQanPyLqwn',
#   'track_title': 'Running After You',
#   'track_url': 'https://open.spotify.com/track/6cRkm1iHWDYpkQanPyLqwn',
#   'track_popularity': 43,
#   'release_date': '2016-07-22',
#   'album_uri': 'spotify:album:4HHYtQOxAGeD7As8jhrpyF'},
#  {'id': 23,
#   'track_uri': 'spotify:track:5A3fPy30SN2wuzrahpcxvV',
#   'track_title': 'Don\'t Give Up On Me - (From "Five Feet Apart")',
#   'track_url': 'https://open.spotify.com/track/5A3fPy30SN2wuzrahpcxvV',
#   'track_popularity': 74,
#   'release_date': '2019-07-26',
#   'album_uri': 'spotify:album:20mlgqmD6YJwkNuAfLRcDC'},
#  {'id': 24,
#   'track_uri': 'spotify:track:727Z2S2mtNH46CbP9EWPwY',
#   'track_title': 'If You Love Her',
#   'track_url': 'https://open.spotify.com/track/727Z2S2mtNH46CbP9EWPwY',
#   'track_popularity': 76,
#   'release_date': '2020-09-30',
#   'album_uri': 'spotify:album:5hgwPA78vCrhEDaTazNMyR'},
#  {'id': 25,
#   'track_uri': 'spotify:track:4euXJuErBCqH2LEApfxI6i',
#   'track_title': 'broken - acoustic',
#   'track_url': 'https://open.spotify.com/track/4euXJuErBCqH2LEApfxI6i',
#   'track_popularity': 55,
#   'release_date': '2018-11-16',
#   'album_uri': 'spotify:album:0BZ9f0pDywBiIHobwdplvh'},
#  {'id': 26,
#   'track_uri': 'spotify:track:185cmBOExC1AHWe3xrbmQ8',
#   'track_title': 'Haunt You (feat. chloe moriondo)',
#   'track_url': 'https://open.spotify.com/track/185cmBOExC1AHWe3xrbmQ8',
#   'track_popularity': 45,
#   'release_date': '2020-10-23',
#   'album_uri': 'spotify:album:1MqtK6ggc4XnWH7y7XvUjD'},
#  {'id': 27,
#   'track_uri': 'spotify:track:2PvZNsVhnHvhXQG2SAYDTp',
#   'track_title': "Sailor's Heart",
#   'track_url': 'https://open.spotify.com/track/2PvZNsVhnHvhXQG2SAYDTp',
#   'track_popularity': 35,
#   'release_date': '2019-10-04',
#   'album_uri': 'spotify:album:0onhz96ZjCqSainuMn8456'},
#  {'id': 28,
#   'track_uri': 'spotify:track:1uwvhkMMQlnaHQ8wtldM7K',
#   'track_title': 'Simple Life',
#   'track_url': 'https://open.spotify.com/track/1uwvhkMMQlnaHQ8wtldM7K',
#   'track_popularity': 37,
#   'release_date': '2012-01-01',
#   'album_uri': 'spotify:album:6wq7YT3Nq1Qq5tB6DC8Ok7'},
#  {'id': 29,
#   'track_uri': 'spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL',
#   'track_title': 'Photograph',
#   'track_url': 'https://open.spotify.com/track/1HNkqx9Ahdgi1Ixy2xkKkL',
#   'track_popularity': 87,
#   'release_date': '2014-06-21',
#   'album_uri': 'spotify:album:1xn54DMo2qIqBuMqHtUsFd'},
#  {'id': 30,
#   'track_uri': 'spotify:track:2FV0C1Ki4gnDal2YyMPHcC',
#   'track_title': 'In Love Now',
#   'track_url': 'https://open.spotify.com/track/2FV0C1Ki4gnDal2YyMPHcC',
#   'track_popularity': 9,
#   'release_date': '2020-02-13',
#   'album_uri': 'spotify:album:5WO0CLrgBF52aqce052E2w'},
#  {'id': 31,
#   'track_uri': 'spotify:track:07HeFSqsEGq4eWyerDrW1a',
#   'track_title': 'Back Home',
#   'track_url': 'https://open.spotify.com/track/07HeFSqsEGq4eWyerDrW1a',
#   'track_popularity': 61,
#   'release_date': '2014-08-05',
#   'album_uri': 'spotify:album:0XUNG1cssmwHh22loRqKdJ'},
#  {'id': 32,
#   'track_uri': 'spotify:track:0SL50BWlNr0RThIgL5swJK',
#   'track_title': 'Let It Be',
#   'track_url': 'https://open.spotify.com/track/0SL50BWlNr0RThIgL5swJK',
#   'track_popularity': 34,
#   'release_date': '2018-11-23',
#   'album_uri': 'spotify:album:3ZPcwX7RlFXDY5DvbuBYhk'},
#  {'id': 33,
#   'track_uri': 'spotify:track:3H3r2nKWa3Yk5gt8xgmsEt',
#   'track_title': 'This City',
#   'track_url': 'https://open.spotify.com/track/3H3r2nKWa3Yk5gt8xgmsEt',
#   'track_popularity': 77,
#   'release_date': '2019-12-11',
#   'album_uri': 'spotify:album:5waiE6DS2ntWF3Q0yekJUm'},
#  {'id': 34,
#   'track_uri': 'spotify:track:4IQkfUsrwXol38VV3U7t7T',
#   'track_title': 'Run (feat. Ed Sheeran) (Taylor’s Version) (From The Vault)',
#   'track_url': 'https://open.spotify.com/track/4IQkfUsrwXol38VV3U7t7T',
#   'track_popularity': 72,
#   'release_date': '2021-11-12',
#   'album_uri': 'spotify:album:6kZ42qRrzov54LcAk4onW9'},
#  {'id': 35,
#   'track_uri': 'spotify:track:6lY36UhtKLMIMdnVRFVvBj',
#   'track_title': 'All I Need',
#   'track_url': 'https://open.spotify.com/track/6lY36UhtKLMIMdnVRFVvBj',
#   'track_popularity': 48,
#   'release_date': '2019-04-26',
#   'album_uri': 'spotify:album:72RUi9PjG1G3duahf11d8T'},
#  {'id': 36,
#   'track_uri': 'spotify:track:40osuXexZYmw3s5Eh2rAWo',
#   'track_title': 'It Should Have Been You',
#   'track_url': 'https://open.spotify.com/track/40osuXexZYmw3s5Eh2rAWo',
#   'track_popularity': 44,
#   'release_date': '2021-02-26',
#   'album_uri': 'spotify:album:7bZ1DjDfuU0IFi0eYnntbD'},
#  {'id': 37,
#   'track_uri': 'spotify:track:6VdjmtfC5V5sJCJHTdFosn',
#   'track_title': 'The Nights',
#   'track_url': 'https://open.spotify.com/track/6VdjmtfC5V5sJCJHTdFosn',
#   'track_popularity': 52,
#   'release_date': '2021-11-05',
#   'album_uri': 'spotify:album:35Go0KvxowPYtiGozuGVwz'},
#  {'id': 38,
#   'track_uri': 'spotify:track:7zODPHkwNgDFZzhv5NhhVw',
#   'track_title': 'Only A Lifetime',
#   'track_url': 'https://open.spotify.com/track/7zODPHkwNgDFZzhv5NhhVw',
#   'track_popularity': 52,
#   'release_date': '2021-10-15',
#   'album_uri': 'spotify:album:3KChz6qdEH9AfHE6VCBshZ'},
#  {'id': 39,
#   'track_uri': 'spotify:track:4vYGDBF9aI3Ro8RbMqKLIb',
#   'track_title': 'Emily',
#   'track_url': 'https://open.spotify.com/track/4vYGDBF9aI3Ro8RbMqKLIb',
#   'track_popularity': 0,
#   'release_date': '2020-07-03',
#   'album_uri': 'spotify:album:4ApVfr2gmTFvwKgJRF6szr'},
#  {'id': 40,
#   'track_uri': 'spotify:track:6Iocm6VMu6bVNYwiDoyQFW',
#   'track_title': 'Coming Home',
#   'track_url': 'https://open.spotify.com/track/6Iocm6VMu6bVNYwiDoyQFW',
#   'track_popularity': 70,
#   'release_date': '2010-01-01',
#   'album_uri': 'spotify:album:2psjRixnoePs8ZqE8cuU5Z'},
#  {'id': 41,
#   'track_uri': 'spotify:track:0lQaP3ttoUjMprcvRu3yeI',
#   'track_title': 'Always',
#   'track_url': 'https://open.spotify.com/track/0lQaP3ttoUjMprcvRu3yeI',
#   'track_popularity': 66,
#   'release_date': '2018-10-19',
#   'album_uri': 'spotify:album:3t31ldCb4oXOYSKXyGfaUA'},
#  {'id': 42,
#   'track_uri': 'spotify:track:3oL3XRtkP1WVbMxf7dtTdu',
#   'track_title': 'The One That Got Away',
#   'track_url': 'https://open.spotify.com/track/3oL3XRtkP1WVbMxf7dtTdu',
#   'track_popularity': 73,
#   'release_date': '2012-03-12',
#   'album_uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#  {'id': 43,
#   'track_uri': 'spotify:track:1hUXDEqjNIIbfjTcaz3jzb',
#   'track_title': 'Like the Movies',
#   'track_url': 'https://open.spotify.com/track/1hUXDEqjNIIbfjTcaz3jzb',
#   'track_popularity': 72,
#   'release_date': '2021-04-30',
#   'album_uri': 'spotify:album:7pooeoqY4uJkTaW70qxm3z'},
#  {'id': 44,
#   'track_uri': 'spotify:track:06vNG6CiV4k8oNA0wUUAO7',
#   'track_title': 'Until I Found You - Piano Version',
#   'track_url': 'https://open.spotify.com/track/06vNG6CiV4k8oNA0wUUAO7',
#   'track_popularity': 71,
#   'release_date': '2022-03-11',
#   'album_uri': 'spotify:album:6126tYz1txFtCrM0pDbEhc'},
#  {'id': 45,
#   'track_uri': 'spotify:track:6T1zHElTuU8UgfDwomdetB',
#   'track_title': 'Someone To You - Acoustic',
#   'track_url': 'https://open.spotify.com/track/6T1zHElTuU8UgfDwomdetB',
#   'track_popularity': 56,
#   'release_date': '2020-05-14',
#   'album_uri': 'spotify:album:2fll9e8DLt71PNZ27UQNqm'},
#  {'id': 46,
#   'track_uri': 'spotify:track:2FJOisgGYaZ2AAkipoRXEg',
#   'track_title': 'You Feel Like Home',
#   'track_url': 'https://open.spotify.com/track/2FJOisgGYaZ2AAkipoRXEg',
#   'track_popularity': 45,
#   'release_date': '2019-02-22',
#   'album_uri': 'spotify:album:06x2swmcWFDIwpuLh3DY6R'},
#  {'id': 47,
#   'track_uri': 'spotify:track:2CSrG5fnBpcdfPXg7sJUBi',
#   'track_title': 'The Book of You & I',
#   'track_url': 'https://open.spotify.com/track/2CSrG5fnBpcdfPXg7sJUBi',
#   'track_popularity': 63,
#   'release_date': '2020-05-29',
#   'album_uri': 'spotify:album:3SzqS1H5dj8f450YhV9YbP'},
#  {'id': 48,
#   'track_uri': 'spotify:track:5GzgEC6pWf1USZsCtkG8yC',
#   'track_title': 'Paper Planes',
#   'track_url': 'https://open.spotify.com/track/5GzgEC6pWf1USZsCtkG8yC',
#   'track_popularity': 61,
#   'release_date': '2020-03-13',
#   'album_uri': 'spotify:album:1k4PWPO9n9mMQyh1WGXog0'},
#  {'id': 49,
#   'track_uri': 'spotify:track:47GyYwSDBMydOfZWazUbZP',
#   'track_title': 'You Set My World On Fire',
#   'track_url': 'https://open.spotify.com/track/47GyYwSDBMydOfZWazUbZP',
#   'track_popularity': 53,
#   'release_date': '2017-07-04',
#   'album_uri': 'spotify:album:2S3aGD9BE0D9XWOr9S7Sol'},
#  {'id': 50,
#   'track_uri': 'spotify:track:4Z5LVvODOf8KDgxa0DCwG1',
#   'track_title': "i don't wanna know - acoustic",
#   'track_url': 'https://open.spotify.com/track/4Z5LVvODOf8KDgxa0DCwG1',
#   'track_popularity': 3,
#   'release_date': '2020-05-29',
#   'album_uri': 'spotify:album:0BYCTsWZVvFKhjtlzIYNxd'},
#  {'id': 51,
#   'track_uri': 'spotify:track:2PR4jVXzyjCky2PkONvipq',
#   'track_title': 'Favorite T-Shirt - Acoustic',
#   'track_url': 'https://open.spotify.com/track/2PR4jVXzyjCky2PkONvipq',
#   'track_popularity': 56,
#   'release_date': '2019-11-08',
#   'album_uri': 'spotify:album:6h8LWfRQHp7Jef1EChIhEM'},
#  {'id': 52,
#   'track_uri': 'spotify:track:58KjkHLf5nt4lyMAdlh5jS',
#   'track_title': 'Even If the Sky Is Falling Down',
#   'track_url': 'https://open.spotify.com/track/58KjkHLf5nt4lyMAdlh5jS',
#   'track_popularity': 46,
#   'release_date': '2019-12-27',
#   'album_uri': 'spotify:album:1PGuZTbSFftSPAgoADL5t1'},
#  {'id': 53,
#   'track_uri': 'spotify:track:3bsRMvQja4huvPWo1S5ONc',
#   'track_title': 'if this is the last time',
#   'track_url': 'https://open.spotify.com/track/3bsRMvQja4huvPWo1S5ONc',
#   'track_popularity': 63,
#   'release_date': '2020-10-02',
#   'album_uri': 'spotify:album:6tmSIFaEjxAtuYwPq9FaFP'},
#  {'id': 54,
#   'track_uri': 'spotify:track:6xGruZOHLs39ZbVccQTuPZ',
#   'track_title': 'Glimpse of Us',
#   'track_url': 'https://open.spotify.com/track/6xGruZOHLs39ZbVccQTuPZ',
#   'track_popularity': 85,
#   'release_date': '2022-06-10',
#   'album_uri': 'spotify:album:6ZZvx0aefZV3LKa053fn71'},
#  {'id': 55,
#   'track_uri': 'spotify:track:4iUCMluJ10iYvl4SZVl2Sx',
#   'track_title': 'Nexus (Is It Over)',
#   'track_url': 'https://open.spotify.com/track/4iUCMluJ10iYvl4SZVl2Sx',
#   'track_popularity': 50,
#   'release_date': '2022-07-01',
#   'album_uri': 'spotify:album:5m9ranB9XySdeWXQxaEEAM'},
#  {'id': 56,
#   'track_uri': 'spotify:track:3nRTgSjfIrqxIMpDrCD0XA',
#   'track_title': "It's You",
#   'track_url': 'https://open.spotify.com/track/3nRTgSjfIrqxIMpDrCD0XA',
#   'track_popularity': 37,
#   'release_date': '2019-05-01',
#   'album_uri': 'spotify:album:5yDzqSgL4foY1OryEjSOv5'},
#  {'id': 57,
#   'track_uri': 'spotify:track:4yNk9iz9WVJikRFle3XEvn',
#   'track_title': 'golden hour',
#   'track_url': 'https://open.spotify.com/track/4yNk9iz9WVJikRFle3XEvn',
#   'track_popularity': 84,
#   'release_date': '2022-10-03',
#   'album_uri': 'spotify:album:2uiQo0DIcriQKVm5ivXuDO'},
#  {'id': 58,
#   'track_uri': 'spotify:track:2AUMUa4urS1KyEB2VtclSC',
#   'track_title': 'Then Some (feat. Walker Hayes)',
#   'track_url': 'https://open.spotify.com/track/2AUMUa4urS1KyEB2VtclSC',
#   'track_popularity': 43,
#   'release_date': '2021-01-29',
#   'album_uri': 'spotify:album:1pm50OHYxgtr4M8Bdn4piC'},
#  {'id': 59,
#   'track_uri': 'spotify:track:1TnLvOZrfKuWRcQR6MvkQL',
#   'track_title': 'Pirates Tonight',
#   'track_url': 'https://open.spotify.com/track/1TnLvOZrfKuWRcQR6MvkQL',
#   'track_popularity': 27,
#   'release_date': '2021-01-29',
#   'album_uri': 'spotify:album:1pm50OHYxgtr4M8Bdn4piC'},
#  {'id': 60,
#   'track_uri': 'spotify:track:6gQ2I32ChoaFhmn9ZVHfU3',
#   'track_title': 'Come Home',
#   'track_url': 'https://open.spotify.com/track/6gQ2I32ChoaFhmn9ZVHfU3',
#   'track_popularity': 39,
#   'release_date': '2020-01-31',
#   'album_uri': 'spotify:album:23DTTEm1mM29DXtcEiIMIw'},
#  {'id': 61,
#   'track_uri': 'spotify:track:3GRSqlALWISqLeNncZMbpX',
#   'track_title': 'Mean It',
#   'track_url': 'https://open.spotify.com/track/3GRSqlALWISqLeNncZMbpX',
#   'track_popularity': 0,
#   'release_date': '2019-11-14',
#   'album_uri': 'spotify:album:4aoWQU2gSUjl4AZeCPSo1b'},
#  {'id': 62,
#   'track_uri': 'spotify:track:3dPtXHP0oXQ4HCWHsOA9js',
#   'track_title': '夜に駆ける',
#   'track_url': 'https://open.spotify.com/track/3dPtXHP0oXQ4HCWHsOA9js',
#   'track_popularity': 76,
#   'release_date': '2019-12-15',
#   'album_uri': 'spotify:album:3GzwPyPZCyrqUTaurTaS23'},
#  {'id': 63,
#   'track_uri': 'spotify:track:2vjY3jGKElvqXoaGNEuYef',
#   'track_title': '怪物',
#   'track_url': 'https://open.spotify.com/track/2vjY3jGKElvqXoaGNEuYef',
#   'track_popularity': 71,
#   'release_date': '2021-12-01',
#   'album_uri': 'spotify:album:5uStDUB4nlmItpz2AYlFtd'},
#  {'id': 64,
#   'track_uri': 'spotify:track:4BE1OloRc9xwjyqA4wFFuN',
#   'track_title': 'あの夢をなぞって',
#   'track_url': 'https://open.spotify.com/track/4BE1OloRc9xwjyqA4wFFuN',
#   'track_popularity': 67,
#   'release_date': '2020-01-18',
#   'album_uri': 'spotify:album:6VtHuuDn351LBXwpxmvZqt'},
#  {'id': 65,
#   'track_uri': 'spotify:track:2w9nvs1ByWUGkED4M0ug34',
#   'track_title': 'Unloving You',
#   'track_url': 'https://open.spotify.com/track/2w9nvs1ByWUGkED4M0ug34',
#   'track_popularity': 65,
#   'release_date': '2022-03-22',
#   'album_uri': 'spotify:album:0eljMEeLbmyj77sh2fzo4j'},
#  {'id': 66,
#   'track_uri': 'spotify:track:3TcL0dyCMyr0kyTTc4NLgI',
#   'track_title': 'Who Says',
#   'track_url': 'https://open.spotify.com/track/3TcL0dyCMyr0kyTTc4NLgI',
#   'track_popularity': 78,
#   'release_date': '2011-01-01',
#   'album_uri': 'spotify:album:49yHvRh1cOfLcEKukEP7Ox'},
#  {'id': 67,
#   'track_uri': 'spotify:track:38o5lj4mbLK34vQkJUlMrg',
#   'track_title': 'London',
#   'track_url': 'https://open.spotify.com/track/38o5lj4mbLK34vQkJUlMrg',
#   'track_popularity': 64,
#   'release_date': '2018-12-14',
#   'album_uri': 'spotify:album:75FQknIE9CKLj66rYEqoaD'},
#  {'id': 68,
#   'track_uri': 'spotify:track:5Fy46k558RutcQ14N3lx7p',
#   'track_title': 'Play Pretend',
#   'track_url': 'https://open.spotify.com/track/5Fy46k558RutcQ14N3lx7p',
#   'track_popularity': 24,
#   'release_date': '2020-12-11',
#   'album_uri': 'spotify:album:6LM1ve3neiudZY3u6CyIzV'},
#  {'id': 69,
#   'track_uri': 'spotify:track:77MdvMx9L4ZQuLhhn3o21h',
#   'track_title': 'If the World Was Ending (feat. Julia Michaels)',
#   'track_url': 'https://open.spotify.com/track/77MdvMx9L4ZQuLhhn3o21h',
#   'track_popularity': 75,
#   'release_date': '2021-06-25',
#   'album_uri': 'spotify:album:538BxdI7oOQykSkEtyjhUD'},
#  {'id': 70,
#   'track_uri': 'spotify:track:0j1Ia2lQWrcXrQZI4AdJlk',
#   'track_title': 'IDK You Yet',
#   'track_url': 'https://open.spotify.com/track/0j1Ia2lQWrcXrQZI4AdJlk',
#   'track_popularity': 77,
#   'release_date': '2020-06-23',
#   'album_uri': 'spotify:album:2MV7PrKdCcislKUAPMyEA2'},
#  {'id': 71,
#   'track_uri': 'spotify:track:2M8Dre5FFAjt43a9NglGgm',
#   'track_title': 'She',
#   'track_url': 'https://open.spotify.com/track/2M8Dre5FFAjt43a9NglGgm',
#   'track_popularity': 52,
#   'release_date': '2019-12-06',
#   'album_uri': 'spotify:album:6imRhQCpFOLRWvBf9R0ncF'},
#  {'id': 72,
#   'track_uri': 'spotify:track:1mnutbOQBQMUBT96qkFSrs',
#   'track_title': "I'll Be There",
#   'track_url': 'https://open.spotify.com/track/1mnutbOQBQMUBT96qkFSrs',
#   'track_popularity': 39,
#   'release_date': '2019-04-26',
#   'album_uri': 'spotify:album:72RUi9PjG1G3duahf11d8T'},
#  {'id': 73,
#   'track_uri': 'spotify:track:1aEsTgCsv8nOjEgyEoRCpS',
#   'track_title': 'this is how you fall in love',
#   'track_url': 'https://open.spotify.com/track/1aEsTgCsv8nOjEgyEoRCpS',
#   'track_popularity': 74,
#   'release_date': '2021-02-05',
#   'album_uri': 'spotify:album:0A9eIFTz09ciHqCHJNYyf2'},
#  {'id': 74,
#   'track_uri': 'spotify:track:4R9omgqjDe7PAvWMOwgrVK',
#   'track_title': 'Love Like Mine',
#   'track_url': 'https://open.spotify.com/track/4R9omgqjDe7PAvWMOwgrVK',
#   'track_popularity': 38,
#   'release_date': '2019-06-03',
#   'album_uri': 'spotify:album:11MFvud6qxxIbpBPclylhg'},
#  {'id': 75,
#   'track_uri': 'spotify:track:3iTb61NCoUhOvbChmdhcRM',
#   'track_title': 'All Too Well',
#   'track_url': 'https://open.spotify.com/track/3iTb61NCoUhOvbChmdhcRM',
#   'track_popularity': 45,
#   'release_date': '2021-01-29',
#   'album_uri': 'spotify:album:6efKXWSoIcByFOuxyu7Sh3'},
#  {'id': 76,
#   'track_uri': 'spotify:track:0jQGwGtEuSmjvVS2iKEOgG',
#   'track_title': 'Like No One Does',
#   'track_url': 'https://open.spotify.com/track/0jQGwGtEuSmjvVS2iKEOgG',
#   'track_popularity': 65,
#   'release_date': '2020-12-20',
#   'album_uri': 'spotify:album:3DyTbFaUxKb9LIGLjp1Dxx'},
#  {'id': 77,
#   'track_uri': 'spotify:track:08MFgEQeVLF37EyZ7jcwLc',
#   'track_title': 'Pano',
#   'track_url': 'https://open.spotify.com/track/08MFgEQeVLF37EyZ7jcwLc',
#   'track_popularity': 79,
#   'release_date': '2021-12-06',
#   'album_uri': 'spotify:album:1HJ34zQqSqNvZeO2W6dE01'},
#  {'id': 78,
#   'track_uri': 'spotify:track:2XDLLEFWTuCRBZy21fRpcm',
#   'track_title': 'Yumetourou',
#   'track_url': 'https://open.spotify.com/track/2XDLLEFWTuCRBZy21fRpcm',
#   'track_popularity': 0,
#   'release_date': '2016-08-24',
#   'album_uri': 'spotify:album:3qNUgzsX6eVSsXHX3B7uHA'},
#  {'id': 79,
#   'track_uri': 'spotify:track:58qX77t2VWMWcycsh9zKLc',
#   'track_title': "i don't want to watch the world end with someone else",
#   'track_url': 'https://open.spotify.com/track/58qX77t2VWMWcycsh9zKLc',
#   'track_popularity': 69,
#   'release_date': '2020-05-08',
#   'album_uri': 'spotify:album:610pjYthQHEHqSdF8kCTcP'},
#  {'id': 80,
#   'track_uri': 'spotify:track:3Eb5sztvEMa0Mqnb8DUAlU',
#   'track_title': 'Come Inside Of My Heart',
#   'track_url': 'https://open.spotify.com/track/3Eb5sztvEMa0Mqnb8DUAlU',
#   'track_popularity': 78,
#   'release_date': '2019-01-18',
#   'album_uri': 'spotify:album:5mGR6qKnpILzSzq1yyAUXk'},
#  {'id': 81,
#   'track_uri': 'spotify:track:4MsOWApwFYowURf1CsztXP',
#   'track_title': 'Sinderela',
#   'track_url': 'https://open.spotify.com/track/4MsOWApwFYowURf1CsztXP',
#   'track_popularity': 60,
#   'release_date': '2019-04-05',
#   'album_uri': 'spotify:album:75CKoVyanOM8WDOVpvNhcv'},
#  {'id': 82,
#   'track_uri': 'spotify:track:5Fy46k558RutcQ14N3lx7p',
#   'track_title': 'Play Pretend',
#   'track_url': 'https://open.spotify.com/track/5Fy46k558RutcQ14N3lx7p',
#   'track_popularity': 24,
#   'release_date': '2020-12-11',
#   'album_uri': 'spotify:album:6LM1ve3neiudZY3u6CyIzV'},
#  {'id': 83,
#   'track_uri': 'spotify:track:6hYvw3LLTViP2mT4MpDNmT',
#   'track_title': 'Grow as We Go',
#   'track_url': 'https://open.spotify.com/track/6hYvw3LLTViP2mT4MpDNmT',
#   'track_popularity': 64,
#   'release_date': '2019-03-29',
#   'album_uri': 'spotify:album:2AluSp6sapRu17yc4r2a5F'},
#  {'id': 84,
#   'track_uri': 'spotify:track:395KzBy0bkb57dEvg6cfzJ',
#   'track_title': 'Falling Like The Stars',
#   'track_url': 'https://open.spotify.com/track/395KzBy0bkb57dEvg6cfzJ',
#   'track_popularity': 72,
#   'release_date': '2019-10-18',
#   'album_uri': 'spotify:album:0cm9LOQUBK3JUgyoRj238z'},
#  {'id': 85,
#   'track_uri': 'spotify:track:2nRaAETFbe39JVCFSVDkcc',
#   'track_title': "I'll Be Waiting",
#   'track_url': 'https://open.spotify.com/track/2nRaAETFbe39JVCFSVDkcc',
#   'track_popularity': 66,
#   'release_date': '2023-02-10',
#   'album_uri': 'spotify:album:3ZXDCsmvSAVNRC7TYjOfWv'},
#  {'id': 86,
#   'track_uri': 'spotify:track:3b5Li4QKDVBx1x7fQuu54a',
#   'track_title': 'Tired',
#   'track_url': 'https://open.spotify.com/track/3b5Li4QKDVBx1x7fQuu54a',
#   'track_popularity': 65,
#   'release_date': '2017-05-19',
#   'album_uri': 'spotify:album:1q1ayQAYMOacFE2fkXbkv2'},
#  {'id': 87,
#   'track_uri': 'spotify:track:4h65LIwmpXcrjwji5fuzDQ',
#   'track_title': 'EP. 4: Important',
#   'track_url': 'https://open.spotify.com/track/4h65LIwmpXcrjwji5fuzDQ',
#   'track_popularity': 51,
#   'release_date': '2022-07-07',
#   'album_uri': 'spotify:album:46QAoxts6RpE8zO9KnIBZi'},
#  {'id': 88,
#   'track_uri': 'spotify:track:771LchWwP7QMx6uAHIQKMW',
#   'track_title': 'Fine',
#   'track_url': 'https://open.spotify.com/track/771LchWwP7QMx6uAHIQKMW',
#   'track_popularity': 44,
#   'release_date': '2021-07-02',
#   'album_uri': 'spotify:album:4gFWVvvbM0KHjgh6gRGSaX'},
#  {'id': 89,
#   'track_uri': 'spotify:track:5bwZjteR12LZdlWbb3BXWu',
#   'track_title': '태양의 후예 (Original Television Soundtrack), Pt. 6 - 말해! 뭐해?',
#   'track_url': 'https://open.spotify.com/track/5bwZjteR12LZdlWbb3BXWu',
#   'track_popularity': 0,
#   'release_date': '2016-03-18',
#   'album_uri': 'spotify:album:6ZyBuakC7gFwtjCAIT7Xzd'},
#  {'id': 90,
#   'track_uri': 'spotify:track:7sQH1uCHZeNcmyTUXkuCIL',
#   'track_title': '記得',
#   'track_url': 'https://open.spotify.com/track/7sQH1uCHZeNcmyTUXkuCIL',
#   'track_popularity': 40,
#   'release_date': '2001-10-18',
#   'album_uri': 'spotify:album:6IgxzPmPjyRen4tUstQ1Ov'},
#  {'id': 91,
#   'track_uri': 'spotify:track:59XuPhDOT636SJ5z17mIUU',
#   'track_title': 'cool',
#   'track_url': 'https://open.spotify.com/track/59XuPhDOT636SJ5z17mIUU',
#   'track_popularity': 50,
#   'release_date': '2023-05-18',
#   'album_uri': 'spotify:album:3m84nUucwMjD3n0OpuhLFW'}]

# %%
df = pd.DataFrame(playlist_audio_features)
df = df[audio_features_list]

before_df = df.copy()
after_df = df.copy()

before_df.describe()
# Out:
#        danceability     energy        key   loudness  speechiness  \
# count     91.000000  91.000000  91.000000  91.000000    91.000000
# mean       0.571055   0.495758   5.670330  -8.488253     0.056271
# std        0.132913   0.210728   3.493025   3.056107     0.063613
# min        0.164000   0.115000   0.000000 -18.502000     0.026500
# 25%        0.498500   0.338500   2.000000 -10.199500     0.031900
# 50%        0.583000   0.457000   6.000000  -8.436000     0.038100
# 75%        0.657500   0.640000   9.000000  -6.265500     0.050100
# max        0.836000   0.927000  11.000000  -1.921000     0.439000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     91.000000         91.000000  91.000000  91.000000   91.000000
# mean       0.495365          0.002865   0.173495   0.418660  120.773846
# std        0.331843          0.018769   0.116136   0.208643   30.898445
# min        0.000802          0.000000   0.011500   0.068000   50.827000
# 25%        0.136500          0.000000   0.104500   0.235500  100.972500
# 50%        0.547000          0.000000   0.126000   0.426000  114.943000
# 75%        0.806000          0.000019   0.192500   0.540000  137.934000
# max        0.966000          0.162000   0.690000   0.864000  210.871000
#
#          duration_ms
# count      91.000000
# mean   203605.582418
# std     37832.776372
# min    127249.000000
# 25%    174628.000000
# 50%    201412.000000
# 75%    229116.000000
# max    315476.000000

# %%
# Step 1: Min-max normalization for selected features
input_data_ranges = {
    'loudness': (-60, 0),
    'tempo': (0, 250),
    'key': (-1, 11)
}
for feature, (feature_min, feature_max) in input_data_ranges.items():
    after_df[feature] = (after_df[feature] - feature_min) / (feature_max - feature_min)

# Step 2: Keep selected audio features
selected_features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo']
filtered_data = after_df[selected_features].copy()

# Step 3: Cube root transformation for selected features
cubed_features = ['speechiness', 'acousticness', 'liveness']
for feature in cubed_features:
    filtered_data[feature] = np.cbrt(filtered_data[feature])

# Step 4: Logarithmic transformation for selected features
log_features = ['energy', 'loudness']
for feature in log_features:
    filtered_data[feature] = np.log1p(filtered_data[feature])

# Step 5: IQR-filtering based on thresholds
lower_thresholds =  {'danceability': 0.16850000000000004, 'energy': 0.14936944969853527, 'loudness': 0.5734535346157168, 
                     'speechiness': 0.11183139278235099, 'acousticness': -0.35285124201451823, 'liveness': 0.20276263879283324, 
                     'valence': -0.24249999999999988, 'tempo': 0.16009000000000007}
upper_thresholds = {'danceability': 1.0525, 'energy': 0.8605850164229211, 'loudness': 0.698995265917933, 
                    'speechiness': 0.6924946680943335, 'acousticness': 1.280417950271011, 'liveness': 0.8754111662234604, 
                    'valence': 1.2494999999999998, 'tempo': 0.7998179999999999}

for feature in selected_features:
    filtered_data[feature] = np.where(
        (filtered_data[feature] >= lower_thresholds[feature]) &
        (filtered_data[feature] <= upper_thresholds[feature]),
        filtered_data[feature],
        np.nan
    )

# Step 6: Min-max Normalization
feature_min = {'danceability': 0.169, 'energy': 0.1501426584297195, 'loudness': 0.5734623376139655, 
               'speechiness': 0.27977873676275317, 'acousticness': 0.0, 'liveness': 0.21074564860592623, 
               'valence': 0.0, 'tempo': 0.164644}

feature_max = {'danceability': 0.991, 'energy': 0.6931471805599453, 'loudness': 0.6983917371326527, 
               'speechiness': 0.692435557262704, 'acousticness': 0.9986648849277057, 'liveness': 0.8750340122833274, 
               'valence': 1.0, 'tempo': 0.799812}

for feature in selected_features:
    if feature in feature_min:
        after_df[feature] = (after_df[feature] - feature_min[feature]) / (feature_max[feature] - feature_min[feature])
    
# Step 7: Calculate playlist vector
playlist_vector = filtered_data.mean()
playlist_vector = (playlist_vector / playlist_vector.sum()).round(4)

playlist_vector = playlist_vector.sort_values(ascending=False)

# Printing Playlist Vector and Playlist Audio Features
average_before = before_df[selected_features].mean()
playlist_audio_features_array = average_before.to_numpy().round(4)

print("Playlist Audio Features:")
print(average_before)
print()
print([int(value * 10000) / 10000 for value in playlist_audio_features_array])
print()

print("Playlist Vector:")
print(playlist_vector)
# Out:
# Playlist Audio Features:
# danceability      0.571055
# energy            0.495758
# loudness         -8.488253
# speechiness       0.056271
# acousticness      0.495365
# liveness          0.173495
# valence           0.418660
# tempo           120.773846
# dtype: float64
#
# [0.5711, 0.4958, -8.4883, 0.0563, 0.4954, 0.1734, 0.4187, 120.7738]
#
# Playlist Vector:
# acousticness    0.1748
# loudness        0.1516
# danceability    0.1402
# liveness        0.1298
# tempo           0.1167
# valence         0.1020
# energy          0.0987
# speechiness     0.0861
# dtype: float64

# %%
track_uri = 'spotify:track:1LeSp4o3CeNhJz3kCWgi6E'
play_track_in_browser(track_uri)
# Out:
# {'id': '', 'track_uri': 'spotify:track:1LeSp4o3CeNhJz3kCWgi6E', 'track_title': 'Just a Dream', 'track_url': 'https://open.spotify.com/track/1LeSp4o3CeNhJz3kCWgi6E', 'track_popularity': 45, 'release_date': '1998-01-01', 'album_uri': 'spotify:album:2RZWkNro2CpwJNubTgPIM2'}
